# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

print(housing.DESCR)

import torch
import torch.nn as nn

for path in sys.path

# start eda
df = pd.DataFrame(housing.data, columns=housing.feature_names)
df['target'] = housing.target

# %%
# plot averooms vs medinc
plt.figure(figsize=(10, 7))
sns.scatterplot(x='AveRooms', y='MedInc', data=df, hue='target')
plt.title('AveRooms vs MedInc')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # plot averooms vs medinc
# ----> 2 plt.figure(figsize=(10, 7))
#       3 sns.scatterplot(x='AveRooms', y='MedInc', data=df, hue='target')
#       4 plt.title('AveRooms vs MedInc')
#
# NameError: name 'plt' is not defined

# %%
# use for loop to plot every feature vs target
for col in df.columns[:-1]:
    plt.figure(figsize=(10, 7))
    sns.scatterplot(x=col, y='target', data=df)
    plt.title(f'{col} vs target')
    plt.show()

# %%
print
# Out:
# hello
